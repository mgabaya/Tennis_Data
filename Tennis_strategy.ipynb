# %% [markdown]
# # Tennis Strategies
#
# In this document, we will be looking at the shot selections of top one-handed backhand players.
#
# **Goal**: Examine and Determine what strategies are useful to use for one-handers in terms of shot selection, set ups, and effectiveness.
#
# Credit for the original data: https://www.kaggle.com/datasets/ryanthomasallen/tennis-match-charting-project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rally = pd.read_csv('Mens/charting-m-stats-Rally.csv', encoding='ISO-8859-1', index_col=False) 
# encoding='ISO-8859-1', , header=0, encoding_errors='replace'
rally.head(10)
# Out:
# /var/folders/10/z7xcjwyj3yjc2tg70_k8qvmw0000gn/T/ipykernel_53781/1782720516.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   rally = pd.read_csv('Mens/charting-m-stats-Rally.csv', encoding='ISO-8859-1', index_col=False)
#                                             match_id    row  pts  pl1_won  \
# 0  19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bo...  Total  132       82
# 1  19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bo...    1-3   64       40
# 2  19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bo...  1-3-1   34       29
# 3  19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bo...  1-3-2   30       11
# 4  19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bo...    4-6   40       27
# 5  19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bo...  4-6-1   19        9
# 6  19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bo...  4-6-2   21       18
# 7  19751219-M-Davis_Cup_World_Group_F-RR-Bjorn_Bo...    7-9   13        5
# ...

# %%
rally.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26725 entries, 0 to 26724
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   match_id      26725 non-null  object
#  1   row           26725 non-null  object
#  2   pts           26725 non-null  int64
#  3   pl1_won       26725 non-null  int64
#  4   pl1_winners   26725 non-null  int64
#  5   pl1_forced    26725 non-null  int64
#  6   pl1_unforced  26725 non-null  int64
#  7   pl2_won       26725 non-null  int64
#  8   pl2_winners   26725 non-null  int64
#  9   pl2_forced    26725 non-null  int64
#  10  pl2_unforced  26725 non-null  int64
# dtypes: int64(9), object(2)
# memory usage: 2.2+ MB

# %%
fed = rally[rally['match_id'].str.contains('ederer')]
fed
# Out:
#                                                 match_id    row  pts  pl1_won  \
# 557      19981005-M-Basel-R32-Andre_Agassi-Roger_Federer  Total  103       62
# 558      19981005-M-Basel-R32-Andre_Agassi-Roger_Federer    1-3   65       37
# 559      19981005-M-Basel-R32-Andre_Agassi-Roger_Federer  1-3-1   36       30
# 560      19981005-M-Basel-R32-Andre_Agassi-Roger_Federer  1-3-2   29        7
# 561      19981005-M-Basel-R32-Andre_Agassi-Roger_Federer    4-6   19       12
# ...                                                  ...    ...  ...      ...
# 26642  20140815-M-Cincinnati_Masters-QF-Andy_Murray-R...  7-9-1   10        7
# 26643  20140815-M-Cincinnati_Masters-QF-Andy_Murray-R...  7-9-2    6        4
# 26644  20140815-M-Cincinnati_Masters-QF-Andy_Murray-R...     10   15        5
# 26645  20140815-M-Cincinnati_Masters-QF-Andy_Murray-R...   10-1   11        3
# 26646  20140815-M-Cincinnati_Masters-QF-Andy_Murray-R...   10-2    4        2
#
# ...

# %%
#ferrero = rally[rally['match_id'].str.contains('errero')]
#ferrero.head(15)

# %%
fed.isna().sum()
# Out:
# match_id        0
# row             0
# pts             0
# pl1_won         0
# pl1_winners     0
# pl1_forced      0
# pl1_unforced    0
# pl2_won         0
# pl2_winners     0
# pl2_forced      0
# pl2_unforced    0
# dtype: int64

# %%
fed_total = fed[fed['row'] == 'Total']
fed_total
# Out:
#                                                 match_id    row  pts  pl1_won  \
# 557      19981005-M-Basel-R32-Andre_Agassi-Roger_Federer  Total  103       62
# 680      20001029-M-Basel-F-Thomas_Enqvist-Roger_Federer  Total  288      145
# 731     20010611-M-Halle-QF-Patrick_Rafter-Roger_Federer  Total  202      102
# 741    20010702-M-Wimbledon-R16-Roger_Federer-Pete_Sa...  Total  370      190
# 864    20030804-M-Canada_Masters-R16-Roger_Federer-To...  Total  108       61
# ...                                                  ...    ...  ...      ...
# 26262     20040711-M-Gstaad-F-Roger_Federer-Igor_Andreev  Total  203      115
# 26340        20011028-M-Basel-F-Tim_Henman-Roger_Federer  Total  180       99
# 26517  20081114-M-Masters_Cup-RR-Roger_Federer-Andy_M...  Total  243      118
# 26556  20070122-M-Australian_Open-R16-Roger_Federer-N...  Total  181      105
# 26634  20140815-M-Cincinnati_Masters-QF-Andy_Murray-R...  Total  136       61
#
# ...

# %%
points = pd.read_csv('Mens/charting-m-points.csv', encoding='ISO-8859-1', index_col=False)
points
# Out:
# /var/folders/10/z7xcjwyj3yjc2tg70_k8qvmw0000gn/T/ipykernel_53781/1884064327.py:1: DtypeWarning: Columns (7,12,24,25,26,31,32,33,34,35,45,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   points = pd.read_csv('Mens/charting-m-points.csv', encoding='ISO-8859-1', index_col=False)
#                                                  match_id   Pt  Set1  Set2  \
# 0       20180520-M-Rome_Masters-F-Rafael_Nadal-Alexand...    1     0     0
# 1       20180520-M-Rome_Masters-F-Rafael_Nadal-Alexand...    2     0     0
# 2       20180520-M-Rome_Masters-F-Rafael_Nadal-Alexand...    3     0     0
# 3       20180520-M-Rome_Masters-F-Rafael_Nadal-Alexand...    4     0     0
# 4       20180520-M-Rome_Masters-F-Rafael_Nadal-Alexand...    5     0     0
# ...                                                   ...  ...   ...   ...
# 331715  19700322-M-New_South_Wales-F-Ken_Rosewall-Rod_...  305     2     2
# ...

# %%
points.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331720 entries, 0 to 331719
# Data columns (total 52 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          331720 non-null  object
#  1   Pt                331720 non-null  int64
#  2   Set1              331720 non-null  int64
#  3   Set2              331720 non-null  int64
#  4   Gm1               331720 non-null  int64
#  5   Gm2               331719 non-null  float64
#  6   Pts               331720 non-null  object
#  7   Gm#               331719 non-null  object
#  8   TbSet             331720 non-null  int64
#  9   TB?               331645 non-null  float64
#  10  TBpt              11049 non-null   float64
#  11  Svr               331720 non-null  int64
#  12  Ret               331720 non-null  object
#  13  Serving           330774 non-null  object
#  14  1st               331720 non-null  object
#  15  2nd               126622 non-null  object
# ...

# %%
fed_points = points[points['match_id'].str.contains('ederer')]
fed_points
# Out:
#                                                  match_id   Pt  Set1  Set2  \
# 6980    20180318-M-Indian_Wells_Masters-F-Roger_Federe...    1     0     0
# 6981    20180318-M-Indian_Wells_Masters-F-Roger_Federe...    2     0     0
# 6982    20180318-M-Indian_Wells_Masters-F-Roger_Federe...    3     0     0
# 6983    20180318-M-Indian_Wells_Masters-F-Roger_Federe...    4     0     0
# 6984    20180318-M-Indian_Wells_Masters-F-Roger_Federe...    5     0     0
# ...                                                   ...  ...   ...   ...
# 289670    19981005-M-Basel-R32-Andre_Agassi-Roger_Federer   99     1     0
# 289671    19981005-M-Basel-R32-Andre_Agassi-Roger_Federer  100     1     0
# 289672    19981005-M-Basel-R32-Andre_Agassi-Roger_Federer  101     1     0
# 289673    19981005-M-Basel-R32-Andre_Agassi-Roger_Federer  102     1     0
# 289674    19981005-M-Basel-R32-Andre_Agassi-Roger_Federer  103     1     0
#
# ...
